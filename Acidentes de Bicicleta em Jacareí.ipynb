# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
df = pd.read_excel('Ciclistas 2016-2017-2018.xlsx')

# %%
df.shape
# Out:
# (228, 9)

# %%
df.describe()
# Out:
#                Nro
# count    86.000000
# mean    540.383721
# std     737.775243
# min       0.000000
# 25%     104.750000
# 50%     242.500000
# 75%     656.000000
# max    3634.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 9 columns):
# Logradouro       223 non-null object
# Nro              86 non-null float64
# Cruzamento       23 non-null object
# Data Hora        228 non-null object
# Bairro           228 non-null object
# Gravidade        228 non-null object
# Tipo Acidente    228 non-null object
# Colunas1         228 non-null object
# Fonte            228 non-null object
# dtypes: float64(1), object(8)
# memory usage: 8.9+ KB

# %%
df.rename(columns={'Logradouro':'Logradouro', 'Nro': 'Nro', 'Cruzamento':'Cruzamento', 'Data Hora': 'DataeHora', 'Bairro': 'Bairro','Gravidade': 'Gravidade', 'Tipo Acidente':'TipoAcidente', 'Colunas1': 'DetalheAcidente', 'Fonte': 'Fonte'}, inplace=True)

# %%
df
# Out:
#                                          Logradouro     Nro  \
# 0                        AV. ELMIRA MARTINS MOREIRA     0.0
# 1                                        AV. AVAREÍ   246.0
# 2                         AV. MAJOR ACÁCIO FERREIRA   724.0
# 3                                      AV. MARGINAL     NaN
# 4                  ROD GAL EURYALE DE JESUS ZERBINE     NaN
# 5                  ROD GAL EURYALE DE JESUS ZERBINE     NaN
# 6                  ROD GAL EURYALE DE JESUS ZERBINE     NaN
# 7                                 RUA ISRAEL ALBINO     NaN
# 8                                               NaN     NaN
# 9                        RUA MÁRIO SIQUEIRA CARDOSO   104.0
# 10                              RUA SANTA TEREZINHA     NaN
# 11     EST FRANCISCO EUGÊNIO AZEVEDO - CHICO BICUDO     NaN
# 12                              AV. PAPA JOÃO XXIII     NaN
# 13                        AV ENG DAVI MONTEIRO LINO     NaN
# 14                        AV ENG DAVI MONTEIRO LINO     NaN
# ...

# %%
df.groupby('Bairro').size().sort_values().tail(20).plot(kind='barh', figsize=(5,5))

# %%
df.query('Bairro == "CENTRO"')['Logradouro'].sort_values().value_counts().tail(20).head(30).plot(kind='barh', figsize=(10,10))

# %%
df.query('Bairro == "CENTRO"')['Logradouro'].value_counts().head(30).plot(kind = 'bar')

# %%
df.groupby('TipoAcidente').size().tail(20).plot(kind='bar', figsize=(5,5))

# %%
df.query('TipoAcidente == "Colisão"')['Logradouro'].value_counts().head(30).plot(kind = 'barh',figsize=(5,8))
